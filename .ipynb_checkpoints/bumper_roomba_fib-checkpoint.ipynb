# %%
# activate project environment
# include these lines of code in any future scripts/notebooks
#---
using Pkg
if !haskey(Pkg.installed(), "AA228FinalProject")
    jenv = joinpath(dirname(@__FILE__()), ".") # this assumes the notebook is in the same dir
    # as the Project.toml file, which should be in top level dir of the project. 
    # Change accordingly if this is not the case.
    Pkg.activate(jenv)
    pkg"add FIB#master"
    #Pkg.update()
end
Pkg.instantiate()
Pkg.build("Cairo")
#---
# Out:
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
#   Updating registry at `~/.julia/registries/JuliaPOMDP`
#   Updating git-repo `https://github.com/JuliaPOMDP/Registry`
#   Updating git-repo `https://github.com/JuliaPOMDP/FIB.jl.git`
#  Resolving package versions...
#   Updating `Project.toml`
#  [no changes]
#   Updating `Manifest.toml`
#  [no changes]
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
#   Updating registry at `~/.julia/registries/JuliaPOMDP`
#   Updating git-repo `https://github.com/JuliaPOMDP/Registry`
#   Building LibCURL ─→ `~/.julia/packages/LibCURL/OoXMv/deps/build.log`
#   Building WinRPM ──→ `~/.julia/packages/WinRPM/Y9QdZ/deps/build.log`
#   Building Homebrew → `~/.julia/packages/Homebrew/l8kUw/deps/build.log`
#   Building Cairo ───→ `~/.julia/packages/Cairo/CXPG1/deps/build.log`

# %%
# import necessary packages
Pkg.add("JLD")
using JLD
using AA228FinalProject
using POMDPs
using FIB # For the solver
using POMDPModels
using POMDPPolicies
using BeliefUpdaters
using ParticleFilters
using POMDPSimulators
using Cairo
using Gtk
using Random
using Printf
# Out:
#  Resolving package versions...
#   Updating `Project.toml`
#  [no changes]
#   Updating `Manifest.toml`
#  [no changes]
# ┌ Info: Precompiling JLD [4138dd39-2aa7-5051-a626-17a0bb65d9c8]
# └ @ Base loading.jl:1186
# ┌ Warning: Module Compat with build ID 6365704415035 is missing from the cache.
# │ This may mean Compat [34da2185-b29b-5c13-b0c7-acf172513d20] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:941
# ┌ Warning: Module Compat with build ID 6365704415035 is missing from the cache.
# │ This may mean Compat [34da2185-b29b-5c13-b0c7-acf172513d20] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:941
# ┌ Warning: Module Compat with build ID 6365704415035 is missing from the cache.
# │ This may mean Compat [34da2185-b29b-5c13-b0c7-acf172513d20] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:941
# ...

# %%
sensor = Bumper()
config = 3 # 1,2, or 3
ds = DiscreteRoombaStateSpace(50, 50, 20)
v_steps = [2,5]
om_steps = [-3*pi/4, -pi/2, -pi/4, 0.0, pi/4, pi/2, 3*pi/4, pi]
aspace = vec(collect(RoombaAct(v,om) for v in v_steps, om in om_steps))
m = RoombaPOMDP(sensor=sensor, mdp=RoombaMDP(sspace=ds, aspace=aspace, config=config, contact_pen=-0.5))
# Out:
# RoombaPOMDP{Bumper,Bool}(Bumper(), RoombaMDP{DiscreteRoombaStateSpace,Array{RoombaAct,1}}
#   v_max: Float64 10.0
#   om_max: Float64 1.0
#   dt: Float64 0.5
#   contact_pen: Float64 -0.5
#   time_pen: Float64 -0.1
#   goal_reward: Float64 10.0
#   stairs_penalty: Float64 -10.0
#   config: Int64 3
#   sspace: DiscreteRoombaStateSpace
#   room: AA228FinalProject.Room
#   aspace: Array{RoombaAct}((16,))
#   _amap: Dict{RoombaAct,Int64}
# )

# %%
fib_solver = FIBSolver(max_iterations=50, tolerance=1e-3, verbose=true)
fib_policy = solve(fib_solver, m)
JLD.save("fib_policy.jld", "fib_policy", fib_policy)
# Out:
# [Iteration 1   ] residual:       10.6
# [Iteration 2   ] residual:        9.6
# [Iteration 3   ] residual:       9.12
# [Iteration 4   ] residual:       8.49
# [Iteration 5   ] residual:       8.06
# [Iteration 6   ] residual:       7.66
# [Iteration 7   ] residual:       7.28
# [Iteration 8   ] residual:       6.91
# [Iteration 9   ] residual:       6.57
# [Iteration 10  ] residual:       6.24
# [Iteration 11  ] residual:       5.93
# [Iteration 12  ] residual:       5.63
# [Iteration 13  ] residual:       5.35
# [Iteration 14  ] residual:       5.08
# [Iteration 15  ] residual:       4.83
# [Iteration 16  ] residual:       4.59
# [Iteration 17  ] residual:       4.36
# [Iteration 18  ] residual:       4.14
# [Iteration 19  ] residual:       3.93
# [Iteration 20  ] residual:       3.74
# [Iteration 21  ] residual:       3.55
# [Iteration 22  ] residual:       3.37
# [Iteration 23  ] residual:        3.2
# [Iteration 24  ] residual:       3.04
# [Iteration 25  ] residual:       2.89
# ...

# %%
# first seed the environment
Random.seed!(4)

# run the simulation
c = @GtkCanvas()
win = GtkWindow(c, "Roomba Environment", 600, 600)
for (t, step) in enumerate(stepthrough(m, fib_policy, belief_updater, max_steps=100))
    @guarded draw(c) do widget
        
        # the following lines render the room, the particles, and the roomba
        ctx = getgc(c)
        set_source_rgb(ctx,1,1,1)
        paint(ctx)
        render(ctx, m, step)
        
        # render some information that can help with debugging
        # here, we render the time-step, the state, and the observation
        move_to(ctx,300,400)
        show_text(ctx, @sprintf("t=%d, state=%s, o=%.3f",t,string(step.s),step.o))
    end
    show(c)
    sleep(0.1) # to slow down the simulation
end

# %%
using Statistics
@load "fib_policy.jld"

num_particles = 5000
resampler = BumperResampler(num_particles)

spf = SimpleParticleFilter(m, resampler)

v_noise_coefficient = 2.0
om_noise_coefficient = 0.5

belief_updater = RoombaParticleFilter(spf, v_noise_coefficient, om_noise_coefficient);

total_rewards = []
num_exp = 24
p = fib_policy
for exp = 1:num_exp
    println(string(exp))
    
    Random.seed!(exp)
    traj_rewards = sum([step.r for step in stepthrough(m,p,belief_updater, max_steps=100)])
    
    push!(total_rewards, traj_rewards)
end

@printf("Mean Total Reward: %.3f, StdErr Total Reward: %.3f", mean(total_rewards), std(total_rewards)/sqrt(num_exp))
@show total_rewards
JLD.save("fib_total_rewards.jld", "fib_total_rewards", total_rewards)
# Out:
# 1
# InterruptException:
#
# Stacktrace:
#  [1] stateindex(::RoombaPOMDP{Bumper,Bool}, ::RoombaState) at /Users/heathershen/Desktop/Stanford/coterm/aut 2018/cs238/CS238-final/src/roomba_env.jl:301
#  [2] unnormalized_util(::AlphaVectorPolicy{RoombaPOMDP{Bumper,Bool},RoombaAct}, ::ParticleCollection{RoombaState}) at /Users/heathershen/.julia/packages/ParticleFilters/oMKH3/src/policies.jl:14
#  [3] action(::AlphaVectorPolicy{RoombaPOMDP{Bumper,Bool},RoombaAct}, ::ParticleCollection{RoombaState}) at /Users/heathershen/.julia/packages/ParticleFilters/oMKH3/src/policies.jl:21
#  [4] action_info at /Users/heathershen/.julia/packages/POMDPModelTools/eHEjm/src/info.jl:30 [inlined]
# ...
